# %%
import numpy as np
import os
import cv2
import einops
import random
import time
from typing import Any, List, Sequence, Tuple
from IPython import display
from matplotlib import pyplot as plt
from matplotlib import animation
from IPython.display import HTML

from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_probability as tfp
import tensorflow as tf

tfd = tfp.distributions

physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
# Out:
# 2024-09-07 21:06:48.138830: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-07 21:06:48.138864: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-07 21:06:48.140470: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-07 21:06:48.285586: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-07 21:06:51.592484: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-07 21:06:51.695274: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-07 21:06:51.695480: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
class CoinRunDataset:
    def __init__(self, data_dir, set='train', batch_size=32):
        self.data_dir = data_dir
        self.set = 'train'
        self.batch_size = batch_size
        self.filenames = os.listdir(data_dir)
        self.max_frames = 20
        self.a_width = 1
        
        self.data_length = len(self.filenames)
        print("Length of %s data: " % set, self.data_length)

    def __len__(self):
        return self.data_length

    def __iter__(self):
        for _ in range(0, self.data_length):
            file_idx = random.randint(0, self.data_length - 1)
            fname = self.filenames[file_idx]
            
            if not fname.endswith('npz'): 
                continue
    
            file_path = os.path.join(self.data_dir, fname)
            data = np.load(file_path)
            img = data['obs']

            video_length = img.shape[0]
            
            action = np.reshape(data['action'], newshape=[-1, self.a_width])
            reward = data['reward']
            done = data['done']
            N = data['N']
            '''
            video_length:  554
            img.shape:  (554, 64, 64, 3)
            action.shape:  (554, 1)
            reward.shape:  (554,)
            done.shape:  (554,)
            N.shape:  (554,)
            '''
            offset = random.randint(0, video_length - self.max_frames - 1)
            
            img = img[offset:offset + self.max_frames]
            action = action[offset:offset + self.max_frames]
            reward = reward[offset:offset + self.max_frames]
            done = done[offset:offset + self.max_frames]
            N = N[offset:offset + self.max_frames]

            yield img, action, reward, done, N

    __call__ = __iter__

data_dir = "record"
ds_gen = CoinRunDataset(data_dir=data_dir, set='train', batch_size=32)
ds = tf.data.Dataset.from_generator(ds_gen, (tf.float32, tf.float32, tf.float32, tf.bool, tf.int16))
# Out:
# Length of train data:  5456
# 2024-09-07 21:06:51.710703: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-07 21:06:51.710916: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-07 21:06:51.711073: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-07 21:06:51.786252: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-07 21:06:51.786433: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-07 21:06:51.786591: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-07 21:06:51.786835: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21817 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:09:00.0, compute capability: 8.6

# %%
# %matplotlib inline

from matplotlib import pyplot as plt
from matplotlib import animation
import random
import cv2
from IPython.display import HTML
from IPython import display

display.clear_output(wait=False)
for idx, data in enumerate(ds):
    video, action, reward, done, N = data
    #print("img.shape: ", img.shape)
    #print("action.shape: ", action.shape)
    #print("reward.shape: ", reward.shape)
    #print("done.shape: ", done.shape)
    #print("N.shape: ", N.shape)
    break

fig = plt.figure()
plt.title('real (left), reconstruction (right)')
plt.axis('off')
im = plt.imshow(video[0, :, :, :])
plt.close()

def init():
    im.set_data(video[0, :, :, :])

def animate(i):
    im.set_data(video[i, :, :, :])
    return im

anim = animation.FuncAnimation(fig, animate, init_func=init, frames=video.shape[0], interval=200) # 200ms = 5 fps
#anim.save('dynamic_images.mp4')
HTML(anim.to_html5_video())
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
class InverseActionPolicy(tf.keras.Model):
  """Inverse Dynamics  network."""
  def __init__(self, num_actions: int, num_hidden_units: int):
    """Initialize."""
    super().__init__()

    self.num_actions = num_actions

    # obs
    self.conv3d_1 = tf.keras.layers.Conv3D(filters=12, kernel_size=(5, 5, 5), padding="same")
    self.conv3d_2 = tf.keras.layers.Conv3D(filters=24, kernel_size=(3, 3, 3), padding="same")
    self.conv3d_3 = tf.keras.layers.Conv3D(filters=48, kernel_size=(1, 1, 1), padding="same")
    self.lstm = tf.keras.layers.LSTM(512, return_sequences=True, return_state=True, kernel_regularizer='l2')
    self.common = layers.Dense(num_hidden_units, activation="relu", kernel_regularizer='l2')

    self.actor = layers.Dense(num_actions, kernel_regularizer='l2')

  def get_config(self):
    config = super().get_config().copy()
    config.update({'num_actions': self.num_actions, 'num_hidden_units': self.num_hidden_units})

    return config
    
  def call(self, state: tf.Tensor, memory_state: tf.Tensor, carry_state: tf.Tensor, training) -> Tuple[tf.Tensor, tf.Tensor, tf.Tensor]:
    #print("state.shape: ", state.shape)

    state = tf.cast(state, tf.float32)

    batch_size = state.shape[0]
    time_step = state.shape[1]

    conv3d_1 = self.conv3d_1(state)
    conv3d_1 = tf.keras.layers.LayerNormalization()(conv3d_1)
    conv3d_1 = tf.keras.layers.ReLU()(conv3d_1)

    conv3d_2 = self.conv3d_2(conv3d_1)
    conv3d_2 = tf.keras.layers.LayerNormalization()(conv3d_2)
    conv3d_2 = layers.ReLU()(conv3d_2)

    conv3d_3 = self.conv3d_3(conv3d_2)
    conv3d_3 = tf.keras.layers.LayerNormalization()(conv3d_3)
      
    conv3d_3 = tf.keras.layers.BatchNormalization()(conv3d_3)
    conv3d_3 = tf.keras.layers.ReLU()(conv3d_3)
    #print("conv3d_3.shape: ", conv3d_3.shape)

    conv3d_reshaped = tf.reshape(conv3d_3, [batch_size, time_step, -1])
    #print("conv3d_reshaped.shape: ", conv3d_reshaped.shape)

    initial_state = (memory_state, carry_state)
    lstm_output, final_memory_state, final_carry_state  = self.lstm(conv3d_reshaped, initial_state=initial_state, training=training)
    #print("lstm_output.shape: ", lstm_output.shape)
      
    X_input = self.common(lstm_output)
    #print("X_input: ", X_input)
      
    pi_latent  = self.actor(X_input)
    #print("pi_latent.shape: ", pi_latent.shape)
    #print("")

    return pi_latent, memory_state, carry_state

num_actions = 7
num_hidden_units = 1024
model = InverseActionPolicy(num_actions, num_hidden_units)

# %%
cce_loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
optimizer = tf.keras.optimizers.Adam(0.0001)

for epoch in range(0, 1000000):
    start_time = time.time()
    
    mean_loss = tf.keras.metrics.Mean()
    for idx, data in enumerate(ds):
        #print("idx: ", idx)
        video, action, reward, done, N = data
        #print("video.shape: ", video.shape)

        memory_state = tf.zeros([1,512], dtype=np.float32)
        carry_state =  tf.zeros([1,512], dtype=np.float32)
        with tf.GradientTape() as tape:
            prediction = model(tf.expand_dims(video, 0), memory_state, carry_state, training=True)
            
            act_pi = prediction[0]
            memory_state = prediction[1]
            carry_state = prediction[2]

            act_dist = tfd.Categorical(logits=act_pi)
            pre_action = act_dist.sample()[0]

            action = tf.cast(tf.squeeze(action), tf.int32)
            action_onehot = tf.one_hot(action, num_actions)
            
            #print("action_onehot.shape: ", action_onehot.shape)
            #print("act_pi[0].shape: ", act_pi[0].shape)

            print("action: ", action)
            print("pre_action: ", pre_action)

            #print("action_onehot.shape: ", action_onehot.shape)
            #print("act_pi[0].shape: ", act_pi[0].shape)
            act_loss = cce_loss(action_onehot, act_pi[0])

            regularization_loss = tf.reduce_sum(model.losses)

            total_loss = act_loss + 1e-5 * regularization_loss

            print('epoch: {}, idx: {}, total_loss: {}'.format(epoch, idx, total_loss))
            print("")
            
            mean_loss(total_loss)

        grads = tape.gradient(total_loss, model.trainable_variables)
        optimizer.apply_gradients(zip(grads, model.trainable_variables))

        if idx % 100 == 0:
            display.clear_output(wait=False)
            
    if epoch % 10 == 0:
        model.save_weights("model/IDM_Model_{0}".format(epoch))
# Out:
# action:  tf.Tensor([1 5 3 6 4 0 3 3 6 4 4 5 0 5 6 6 3 6 4 4], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([1 6 6 6 2 4 2 1 6 5 5 4 0 5 4 6 2 6 3 0], shape=(20,), dtype=int32)
# epoch: 617, idx: 4701, total_loss: 1.1928611993789673
#
# action:  tf.Tensor([6 0 0 2 6 4 5 3 2 1 1 5 2 5 4 6 5 5 5 2], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([2 0 0 1 6 3 3 4 4 0 1 5 6 3 4 4 4 2 0 4], shape=(20,), dtype=int32)
# epoch: 617, idx: 4702, total_loss: 1.4617618322372437
#
# action:  tf.Tensor([6 1 3 6 0 5 6 4 4 6 3 3 2 3 6 5 0 4 3 1], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([6 0 2 6 1 5 3 5 4 3 4 4 4 3 2 2 1 0 3 0], shape=(20,), dtype=int32)
# epoch: 617, idx: 4703, total_loss: 1.3158818483352661
#
# action:  tf.Tensor([5 3 5 2 2 3 0 5 3 3 4 1 1 4 3 0 5 4 2 5], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([6 2 2 2 2 6 1 5 4 4 4 1 2 2 1 2 6 3 3 0], shape=(20,), dtype=int32)
# epoch: 617, idx: 4704, total_loss: 1.2960988283157349
#
# action:  tf.Tensor([1 6 2 6 4 3 0 5 1 6 0 2 4 3 4 2 1 6 1 1], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([4 5 5 4 2 4 0 6 1 6 0 3 0 0 0 1 2 6 1 6], shape=(20,), dtype=int32)
# epoch: 617, idx: 4705, total_loss: 1.2422007322311401
#
# action:  tf.Tensor([1 6 4 6 5 4 2 3 4 1 2 0 0 6 6 4 0 4 3 2], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([1 6 4 3 6 4 4 4 5 1 1 0 0 6 2 4 1 1 0 0], shape=(20,), dtype=int32)
# epoch: 617, idx: 4706, total_loss: 1.2903064489364624
#
# action:  tf.Tensor([6 3 4 5 1 1 5 5 2 0 4 3 3 4 3 1 2 6 1 4], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([5 4 4 2 1 4 5 6 4 1 0 2 2 1 1 2 2 6 0 3], shape=(20,), dtype=int32)
# epoch: 617, idx: 4707, total_loss: 1.3459938764572144
#
# action:  tf.Tensor([3 3 5 3 4 1 2 6 4 6 6 1 5 6 3 1 1 6 5 4], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([2 4 6 5 4 0 3 6 5 5 6 0 6 6 6 1 1 6 3 5], shape=(20,), dtype=int32)
# epoch: 617, idx: 4708, total_loss: 1.1613668203353882
#
# action:  tf.Tensor([6 2 4 6 2 5 2 6 3 3 2 3 0 2 1 6 5 0 3 4], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([5 4 4 3 2 2 3 4 2 3 2 3 0 4 0 6 6 0 4 1], shape=(20,), dtype=int32)
# epoch: 617, idx: 4709, total_loss: 1.4619073867797852
#
# action:  tf.Tensor([1 0 4 2 0 6 2 1 3 3 0 3 2 6 3 3 2 4 4 4], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([2 0 2 4 1 6 3 1 4 4 0 0 2 5 2 3 4 2 5 1], shape=(20,), dtype=int32)
# epoch: 617, idx: 4710, total_loss: 1.4754412174224854
#
# action:  tf.Tensor([1 2 2 3 6 4 0 3 4 4 5 1 6 5 6 4 3 6 6 6], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([4 2 3 3 6 2 0 2 1 4 6 0 1 4 2 2 3 2 3 6], shape=(20,), dtype=int32)
# epoch: 617, idx: 4711, total_loss: 1.9986968040466309
#
# action:  tf.Tensor([3 5 5 3 4 1 1 2 3 2 6 4 0 6 4 1 4 3 6 3], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([4 6 6 5 4 1 0 3 3 0 5 4 1 6 3 0 2 1 6 0], shape=(20,), dtype=int32)
# epoch: 617, idx: 4712, total_loss: 1.2536027431488037
#
# action:  tf.Tensor([3 6 5 0 1 3 3 5 3 6 1 3 3 2 6 4 4 1 5 5], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([4 6 5 0 0 1 2 5 2 5 1 0 3 3 5 5 3 1 5 3], shape=(20,), dtype=int32)
# epoch: 617, idx: 4713, total_loss: 1.1283526420593262
#
# action:  tf.Tensor([4 1 3 5 3 2 6 6 0 6 0 1 1 5 1 5 2 0 6 6], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([2 1 0 6 3 3 6 2 1 5 0 4 2 5 1 5 4 0 6 1], shape=(20,), dtype=int32)
# epoch: 617, idx: 4714, total_loss: 0.9984317421913147
#
# action:  tf.Tensor([4 5 0 4 6 6 4 4 6 2 6 0 4 5 0 5 4 1 4 3], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([3 5 1 0 5 3 6 4 4 6 5 1 4 6 0 6 3 0 1 2], shape=(20,), dtype=int32)
# epoch: 617, idx: 4715, total_loss: 1.2128146886825562
#
# action:  tf.Tensor([6 0 4 3 5 6 5 1 4 5 0 3 5 0 6 6 4 6 6 2], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([6 4 0 1 6 5 2 0 3 6 0 0 6 0 6 4 1 2 0 0], shape=(20,), dtype=int32)
# epoch: 617, idx: 4716, total_loss: 1.6549652814865112
#
# action:  tf.Tensor([3 4 4 0 6 5 3 4 2 4 3 6 1 0 6 6 4 3 4 3], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([3 4 6 1 5 6 2 4 6 4 2 6 1 4 6 6 2 3 6 0], shape=(20,), dtype=int32)
# epoch: 617, idx: 4717, total_loss: 1.2976487874984741
#
# action:  tf.Tensor([2 5 6 2 2 2 5 3 6 0 1 6 5 6 3 1 5 2 3 0], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([5 5 4 5 2 3 5 3 6 0 1 6 3 3 5 1 6 6 4 0], shape=(20,), dtype=int32)
# epoch: 617, idx: 4718, total_loss: 1.2157320976257324
#
# action:  tf.Tensor([4 4 1 1 6 2 5 5 6 5 0 5 2 2 2 5 4 3 0 2], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([2 2 0 0 6 5 4 4 6 5 0 5 2 6 4 2 3 2 1 6], shape=(20,), dtype=int32)
# epoch: 617, idx: 4719, total_loss: 1.367459774017334
#
# action:  tf.Tensor([0 4 2 0 1 2 6 2 6 0 6 5 4 2 1 4 5 3 3 2], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([2 4 0 3 3 2 6 4 6 1 6 6 2 4 1 1 5 4 2 5], shape=(20,), dtype=int32)
# epoch: 617, idx: 4720, total_loss: 1.3667893409729004
#
# action:  tf.Tensor([5 6 6 2 1 5 2 5 0 3 0 1 4 2 6 2 5 0 0 3], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([5 6 4 5 1 6 3 0 0 2 0 1 4 1 6 5 2 0 0 5], shape=(20,), dtype=int32)
# epoch: 617, idx: 4721, total_loss: 1.166793942451477
#
# action:  tf.Tensor([5 6 4 1 6 4 1 1 6 5 1 3 4 3 0 6 5 5 2 2], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([6 3 4 1 6 6 1 1 6 4 0 3 2 3 4 5 2 6 3 3], shape=(20,), dtype=int32)
# epoch: 617, idx: 4722, total_loss: 1.1774505376815796
#
# action:  tf.Tensor([0 6 3 2 2 6 0 2 3 6 2 1 1 4 1 4 4 0 2 6], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([0 6 5 6 5 4 0 2 0 5 4 1 2 4 0 1 0 2 2 3], shape=(20,), dtype=int32)
# epoch: 617, idx: 4723, total_loss: 1.2856266498565674
#
# action:  tf.Tensor([3 0 3 6 0 3 5 0 0 3 6 3 3 0 4 2 4 2 5 3], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([0 1 3 6 5 3 4 3 3 3 6 4 6 3 5 3 5 4 6 4], shape=(20,), dtype=int32)
# epoch: 617, idx: 4724, total_loss: 1.671833872795105
#
# action:  tf.Tensor([6 4 4 2 2 5 0 5 1 6 2 0 3 3 3 0 5 2 2 2], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([6 6 2 2 5 5 0 5 1 5 4 1 1 4 3 4 6 3 5 1], shape=(20,), dtype=int32)
# epoch: 617, idx: 4725, total_loss: 1.294730544090271
#
# action:  tf.Tensor([0 0 6 5 5 3 6 6 4 5 4 2 3 2 0 3 5 6 2 0], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([0 0 5 5 4 6 5 6 4 4 2 5 3 4 1 3 5 4 2 2], shape=(20,), dtype=int32)
# epoch: 617, idx: 4726, total_loss: 1.4627007246017456
#
# action:  tf.Tensor([3 0 3 5 4 1 4 1 3 0 0 1 2 4 6 5 5 1 4 2], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([2 4 2 6 4 1 4 1 4 4 2 0 4 0 6 5 2 0 1 1], shape=(20,), dtype=int32)
# epoch: 617, idx: 4727, total_loss: 1.4004881381988525
#
# action:  tf.Tensor([6 6 0 0 0 6 4 4 1 6 4 4 4 2 6 2 4 2 4 5], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([5 4 1 1 1 6 6 6 0 5 2 4 5 3 5 5 5 2 5 4], shape=(20,), dtype=int32)
# epoch: 617, idx: 4728, total_loss: 1.294543981552124
#
# action:  tf.Tensor([0 5 3 1 0 5 0 5 1 1 4 4 3 0 5 3 0 4 4 0], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([1 5 2 0 3 5 1 5 0 4 3 0 2 2 6 4 0 1 4 4], shape=(20,), dtype=int32)
# epoch: 617, idx: 4729, total_loss: 1.186797022819519
#
# action:  tf.Tensor([6 6 4 5 6 6 2 4 2 2 2 2 4 4 5 1 2 2 6 0], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([5 5 2 6 4 4 5 2 2 6 2 0 3 4 4 0 1 0 5 6], shape=(20,), dtype=int32)
# epoch: 617, idx: 4730, total_loss: 1.3343846797943115
#
# action:  tf.Tensor([4 6 2 5 1 4 6 5 4 5 2 0 4 4 0 1 4 4 1 1], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([3 5 5 4 1 1 6 4 6 6 4 0 4 2 1 2 2 0 2 5], shape=(20,), dtype=int32)
# epoch: 617, idx: 4731, total_loss: 1.3851447105407715
#
# action:  tf.Tensor([2 1 4 5 5 3 1 5 4 5 3 6 5 1 3 5 0 5 2 0], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([4 0 1 5 3 4 1 6 4 2 5 5 4 0 4 6 0 6 2 5], shape=(20,), dtype=int32)
# epoch: 617, idx: 4732, total_loss: 1.2442147731781006
#
# action:  tf.Tensor([2 5 6 4 0 6 4 5 5 2 5 1 5 6 4 5 3 0 3 1], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([2 5 5 4 1 5 6 6 6 4 5 1 5 6 2 5 2 1 3 3], shape=(20,), dtype=int32)
# epoch: 617, idx: 4733, total_loss: 1.316260576248169
#
# action:  tf.Tensor([0 4 3 0 2 5 0 2 2 4 4 1 2 1 6 2 5 1 5 5], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([0 3 3 0 3 5 0 2 3 6 3 2 2 3 5 3 3 1 5 3], shape=(20,), dtype=int32)
# epoch: 617, idx: 4734, total_loss: 0.9611637592315674
#
# action:  tf.Tensor([6 0 1 2 2 0 4 3 3 2 3 2 5 5 1 4 2 3 2 4], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([6 1 1 4 1 3 2 2 0 0 3 4 5 4 1 2 2 1 3 6], shape=(20,), dtype=int32)
# epoch: 617, idx: 4735, total_loss: 1.3669217824935913
#
# action:  tf.Tensor([1 1 0 6 2 6 6 4 4 2 3 1 3 2 4 2 6 2 1 1], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([0 4 3 5 6 6 2 4 4 2 2 1 0 2 4 2 5 5 1 0], shape=(20,), dtype=int32)
# epoch: 617, idx: 4736, total_loss: 1.3008253574371338
#
# action:  tf.Tensor([2 1 0 2 6 6 5 0 5 2 2 5 4 5 1 1 6 5 1 6], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([5 0 1 4 6 4 6 1 6 4 5 5 4 5 0 2 5 6 1 4], shape=(20,), dtype=int32)
# epoch: 617, idx: 4737, total_loss: 1.2403285503387451
#
# action:  tf.Tensor([3 1 1 2 1 0 3 1 6 1 0 4 0 5 0 1 6 5 3 0], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([2 1 1 0 3 4 4 2 5 1 0 4 3 6 0 2 6 0 5 3], shape=(20,), dtype=int32)
# epoch: 617, idx: 4738, total_loss: 1.2906055450439453
#
# action:  tf.Tensor([1 6 5 3 2 1 0 5 5 5 4 0 4 2 5 5 5 5 4 3], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([1 5 6 5 5 1 4 5 5 2 4 0 4 4 6 6 3 6 3 3], shape=(20,), dtype=int32)
# epoch: 617, idx: 4739, total_loss: 1.3613561391830444
#
# action:  tf.Tensor([0 3 0 5 4 4 3 2 4 0 3 2 0 2 5 2 2 2 3 6], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([0 1 2 6 3 6 6 5 4 0 0 4 3 0 6 3 2 5 6 3], shape=(20,), dtype=int32)
# epoch: 617, idx: 4740, total_loss: 1.4143263101577759
#
# action:  tf.Tensor([4 4 3 1 1 2 4 3 1 4 5 3 6 6 0 1 1 1 3 6], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([0 4 0 2 0 0 4 0 3 3 6 2 2 6 1 4 3 0 1 0], shape=(20,), dtype=int32)
# epoch: 617, idx: 4741, total_loss: 1.5676711797714233
#
# action:  tf.Tensor([4 1 5 1 5 6 0 3 0 4 2 2 4 5 2 2 4 3 5 4], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([2 1 6 1 5 4 1 2 0 0 1 2 1 6 6 6 5 6 4 4], shape=(20,), dtype=int32)
# epoch: 617, idx: 4742, total_loss: 1.293364405632019
#
# action:  tf.Tensor([2 5 2 2 0 6 0 4 5 2 6 1 2 1 5 4 0 1 3 5], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([2 5 3 3 0 3 2 4 6 3 6 0 0 3 6 4 0 0 1 0], shape=(20,), dtype=int32)
# epoch: 617, idx: 4743, total_loss: 1.1188656091690063
#
# action:  tf.Tensor([1 5 4 5 4 2 4 3 2 2 1 3 2 3 4 1 1 6 0 6], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([1 5 2 4 3 2 5 4 2 2 0 3 2 2 4 2 0 5 1 2], shape=(20,), dtype=int32)
# epoch: 617, idx: 4744, total_loss: 1.2291796207427979
#
# action:  tf.Tensor([0 5 4 0 1 3 4 1 4 3 1 4 1 4 2 2 5 0 1 5], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([3 6 3 1 3 1 4 2 0 4 3 4 4 2 0 4 5 1 4 0], shape=(20,), dtype=int32)
# epoch: 617, idx: 4745, total_loss: 1.3833160400390625
#
# action:  tf.Tensor([5 3 0 4 5 0 3 1 6 3 2 0 6 2 2 6 0 5 2 6], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([3 2 0 4 5 1 3 3 6 4 5 1 6 2 4 6 1 6 2 5], shape=(20,), dtype=int32)
# epoch: 617, idx: 4746, total_loss: 1.0548843145370483
#
# action:  tf.Tensor([2 5 4 2 6 0 5 3 5 1 2 6 6 4 6 0 1 1 2 3], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([3 5 5 3 5 1 5 0 5 1 0 5 5 2 3 1 1 0 2 2], shape=(20,), dtype=int32)
# epoch: 617, idx: 4747, total_loss: 1.1813452243804932
#
# action:  tf.Tensor([6 2 3 0 4 5 6 6 0 1 4 1 6 1 5 4 6 4 1 2], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([5 3 3 0 4 5 6 3 0 1 4 3 6 0 6 2 6 3 1 5], shape=(20,), dtype=int32)
# epoch: 617, idx: 4748, total_loss: 1.1764672994613647
#
# action:  tf.Tensor([0 5 4 2 5 5 0 5 6 2 0 4 0 4 1 5 3 1 1 1], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([1 6 6 4 4 4 0 5 2 5 1 2 2 0 3 5 2 1 0 5], shape=(20,), dtype=int32)
# epoch: 617, idx: 4749, total_loss: 1.2168591022491455
#
# action:  tf.Tensor([6 1 4 3 4 1 5 1 6 4 5 1 5 0 0 1 6 6 3 6], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([6 0 0 4 0 3 6 1 6 6 4 0 5 1 0 3 6 4 3 5], shape=(20,), dtype=int32)
# epoch: 617, idx: 4750, total_loss: 1.1829423904418945
#
# action:  tf.Tensor([1 1 2 4 4 5 6 1 1 2 5 0 3 1 2 6 0 6 6 0], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([0 4 0 4 4 5 6 0 1 0 6 1 2 3 2 5 1 5 3 4], shape=(20,), dtype=int32)
# epoch: 617, idx: 4751, total_loss: 1.2639811038970947
#
# action:  tf.Tensor([5 0 1 6 2 4 0 0 4 3 4 2 3 3 0 6 6 3 1 4], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([5 1 1 5 3 5 0 0 4 4 1 0 1 3 3 5 5 3 0 5], shape=(20,), dtype=int32)
# epoch: 617, idx: 4752, total_loss: 1.320831060409546
#
# action:  tf.Tensor([2 6 3 0 3 1 0 3 0 0 1 2 1 0 4 6 1 0 1 3], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([6 6 3 0 0 1 1 0 4 2 4 0 0 4 4 6 0 2 1 5], shape=(20,), dtype=int32)
# epoch: 617, idx: 4753, total_loss: 1.4318605661392212
#
# action:  tf.Tensor([6 3 3 0 0 5 5 3 6 5 3 4 5 0 2 4 1 6 6 2], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([6 3 5 0 0 5 5 3 6 5 2 4 4 0 4 0 1 6 5 2], shape=(20,), dtype=int32)
# epoch: 617, idx: 4754, total_loss: 1.1489561796188354
#
# action:  tf.Tensor([2 4 3 3 2 0 0 5 5 3 1 5 3 4 4 1 0 5 1 1], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([4 0 0 3 4 3 2 5 4 5 1 5 3 2 5 1 1 5 1 1], shape=(20,), dtype=int32)
# epoch: 617, idx: 4755, total_loss: 1.3148308992385864
#
# action:  tf.Tensor([1 3 3 4 1 5 1 3 1 2 6 2 2 0 6 5 3 5 1 3], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([1 0 1 0 2 5 0 0 3 1 6 3 2 1 6 6 5 3 0 5], shape=(20,), dtype=int32)
# epoch: 617, idx: 4756, total_loss: 1.2479965686798096
#
# action:  tf.Tensor([1 5 6 4 0 1 5 1 5 6 3 2 2 6 0 6 4 5 1 3], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([3 5 6 3 0 3 6 0 5 5 6 5 2 1 2 5 4 3 1 6], shape=(20,), dtype=int32)
# epoch: 617, idx: 4757, total_loss: 1.3213731050491333
#
# action:  tf.Tensor([0 2 2 1 4 4 0 0 1 1 5 6 3 3 1 0 1 1 0 5], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([4 3 3 3 3 4 0 0 1 1 6 6 6 2 1 2 0 2 4 5], shape=(20,), dtype=int32)
# epoch: 617, idx: 4758, total_loss: 1.2935783863067627
#
# action:  tf.Tensor([3 6 0 3 2 3 0 5 1 5 0 6 3 3 3 0 3 3 6 2], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([6 2 1 0 1 0 4 6 1 5 1 6 4 3 5 0 3 2 6 1], shape=(20,), dtype=int32)
# epoch: 617, idx: 4759, total_loss: 1.1978164911270142
#
# action:  tf.Tensor([4 4 3 6 3 4 4 6 0 5 5 3 4 0 1 4 5 3 0 3], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([2 4 4 2 5 5 4 2 2 5 2 3 5 0 4 4 6 3 0 0], shape=(20,), dtype=int32)
# epoch: 617, idx: 4760, total_loss: 1.5868052244186401
#
# action:  tf.Tensor([5 5 5 5 4 4 1 1 6 3 6 5 3 3 6 2 4 1 5 6], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([5 3 4 6 3 6 1 2 5 3 6 4 4 5 2 5 6 1 5 5], shape=(20,), dtype=int32)
# epoch: 617, idx: 4761, total_loss: 1.3834391832351685
#
# action:  tf.Tensor([4 1 1 3 2 1 2 1 4 5 2 2 6 4 4 5 4 1 4 2], shape=(20,), dtype=int32)
# pre_action:  tf.Tensor([5 0 4 2 2 1 1 3 4 5 2 4 6 4 6 6 5 1 0 0], shape=(20,), dtype=int32)
# epoch: 617, idx: 4762, total_loss: 1.3802711963653564
